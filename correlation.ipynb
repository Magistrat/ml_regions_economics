# %%
import pandas as pd

pd.set_option('max_colwidth', None)
pd.set_option('display.max_columns', 100)

# %%
merged_df = pd.read_csv('/Users/konstantinnistratov/PycharmProjects/ml_project_economic_regions/temp/merged_eco_social.csv', sep=';', index_col=0)
# del merged_df['regions.1']

# %%
list_to_get = [
    'Ожидаемая продолжительность жизни при рождении: Все население, число лет',
    'Денежные доходы населения: Медианный среднедушевой денежный доход населения, в месяц, рублей',
    'Денежные доходы населения: Граница бедности, рублей',
    'Денежные доходы населения: Среднемесячная номинальная начисленная заработная плата работников организаций, рублей',
    'Денежные доходы населения: Структура социальных выплат, в процентах',
    'Денежные доходы населения: Реальные денежные доходы: Реальные доходы населения, в процентах к предыдущему году',
    'Удельный вес сельского населения в общей численности населения, оценка на конец года, в процентах',
    'Темпы прироста численности населения, прирост за год, в процентах',
    'Общие коэффициенты смертности, число умерших на 1000 человек населения',
    'Коэффициенты младенческой смертности, число детей, умерших в возрасте до 1 года, на 1000 родившихся живыми',
    'Численность населения, оценка на конец года, тысяч человек',
]

# %%
column_names = merged_df.columns.tolist()
# column_names

# %%
from random import choices
count_of_elements = 10

random_elements = set(choices(column_names, k=count_of_elements))
list_to_get = list(random_elements)
# list_to_get

# %%
check_df = merged_df[list_to_get]

# %%
merged_df
# Out:
#                            Возрастной состав населения: Население старше трудоспособного возраста, оценка на конец года, в процентах от общей численности населения  \
# regions
# Пензенская область                                                                                                                                             28.7
# Ненецкий автономный округ                                                                                                                                      18.8
# Ярославская область                                                                                                                                            27.0
# Краснодарский край                                                                                                                                             24.6
# ...

# %%
numeric_df = check_df.select_dtypes(include='number')

# %%
corr_df = numeric_df.corr()
corr_df
# Out:
#                                                                                                                                                                                                                               Денежные доходы населения: Численность занятых, приходящихся на одного пенсионера, в среднем за год, человек  \
# Денежные доходы населения: Численность занятых, приходящихся на одного пенсионера, в среднем за год, человек                                                                                                                                                                                                                      1.000000
# ...

# %%
# Построение тепловой карты
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(13, 7))
heatmap = sns.heatmap(
    corr_df,
    annot=True,
    fmt='.2f'
)
# heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)
# plt.savefig('/Users/konstantinnistratov/PycharmProjects/ml_project_economic_regions/temp/heatmap.png', dpi=500)
plt.show()
